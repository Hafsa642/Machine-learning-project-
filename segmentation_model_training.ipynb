# %% [markdown]
# <a href="https://colab.research.google.com/github/Hafsa642/Machine-learning-project-/blob/main/segmentation_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  Import Libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
X = df[['Annual Income (k$)', 'Spending Score (1-100)']]

# %%
kmeans = KMeans(n_clusters=5, random_state=0)

# %%
df['Cluster'] = kmeans.fit_predict(X)

# %%
df['Cluster'] = kmeans.fit_predict(X)

# %%
df['Cluster'] = kmeans.fit_predict(X)

# %%
centroids = kmeans.cluster_centers_
print("Centroids:\n", centroids)
# Out:
# Centroids:
#  [[55.2962963  49.51851852]
#  [86.53846154 82.12820513]
#  [88.2        17.11428571]
#  [26.30434783 20.91304348]
#  [25.72727273 79.36363636]]

# %%
plt.scatter(X.iloc[:,0], X.iloc[:,1], c=df['Cluster'])

# %%
plt.scatter(centroids[:,0], centroids[:,1], s=200, marker='X')

# %%
print(df[['Annual Income (k$)', 'Spending Score (1-100)', 'Cluster']].head())
# Out:
#    Annual Income (k$)  Spending Score (1-100)  Cluster
# 0                  15                      39        3
# 1                  15                      81        4
# 2                  16                       6        3
# 3                  16                      77        4
# 4                  17                      40        3
